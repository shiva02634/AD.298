# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars = pd.read_csv(r"C:\Users\Shiva Shankar\Documents\Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
sns.distplot(cars['HP'])
# Out:
# C:\Users\Shiva Shankar\AppData\Local\Temp\ipykernel_8864\2075915428.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['HP'])
# <Axes: xlabel='HP', ylabel='Density'>

# %%
sns.distplot(cars['MPG'])
# Out:
# C:\Users\Shiva Shankar\AppData\Local\Temp\ipykernel_8864\2051910173.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['MPG'])
# <Axes: xlabel='MPG', ylabel='Density'>

# %%
sns.distplot(cars['VOL'])
# Out:
# C:\Users\Shiva Shankar\AppData\Local\Temp\ipykernel_8864\4056332409.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['VOL'])
# <Axes: xlabel='VOL', ylabel='Density'>

# %%
sns.distplot(cars['SP'])
# Out:
# C:\Users\Shiva Shankar\AppData\Local\Temp\ipykernel_8864\2585516942.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['SP'])
# <Axes: xlabel='SP', ylabel='Density'>

# %%
sns.distplot(cars['WT'])
# Out:
# C:\Users\Shiva Shankar\AppData\Local\Temp\ipykernel_8864\1846304077.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars['WT'])
# <Axes: xlabel='WT', ylabel='Density'>

# %%
sns.distplot(x=cars['WT'])
plt.title('Distribution of Weight of vehicles in thousand pounds')
plt.xlabel('Weight in Thousand Pounds')
plt.show()
# Out:
# C:\Users\Shiva Shankar\AppData\Local\Temp\ipykernel_8864\636153068.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=cars['WT'])

# %%
sns.boxplot(x=cars['MPG'])
plt.show()

# %%
sns.boxplot(x=cars['HP'])
plt.show()

# %%
sns.boxplot(x=cars['SP'])
plt.show()

# %%
sns.boxplot(x=cars['VOL'])
plt.show()

# %%
sns.boxplot(x=cars['WT'])
plt.show()

# %%
from seaborn import scatterplot

scatterplot(x=cars['VOL'],y=cars['MPG'])
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
scatterplot(x=cars['MPG'],y=cars['WT'])
# Out:
# <Axes: xlabel='MPG', ylabel='WT'>

# %%
scatterplot(x=cars['SP'],y=cars['VOL'])
# Out:
# <Axes: xlabel='SP', ylabel='VOL'>

# %%
scatterplot(x=cars['WT'],y=cars['VOL'])
# Out:
# <Axes: xlabel='WT', ylabel='VOL'>

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
scatterplot(x=cars['HP'],y=cars['WT'])
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
scatterplot(x=cars['HP'],y=cars['VOL'])
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
scatterplot(x=cars['HP'],y=cars['SP'])
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
scatterplot(x=cars['WT'],y=cars['VOL'])
# Out:
# <Axes: xlabel='WT', ylabel='VOL'>

# %%
scatterplot(x=cars['WT'],y=cars['SP'])
# Out:
# <Axes: xlabel='WT', ylabel='SP'>

# %%
scatterplot(x=cars['VOL'],y=cars['SP'])
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
scatterplot(x=cars['WT'],y=cars['SP'])
# Out:
# <Axes: xlabel='WT', ylabel='SP'>

# %%
 sns.heatmap(cars.corr(),cmap='Blues',annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

cars[['HP','WT','VOL','SP',]]=sc.fit_transform(cars[['HP','WT','VOL','SP']])

# %%
np.round(cars.describe(),2)
# Out:
#            HP    MPG     VOL      SP     WT
# count   81.00  81.00   81.00   81.00  81.00
# mean   117.47  34.42   98.77  121.54  32.41
# std     57.11   9.13   22.30   14.18   7.49
# min     49.00  12.10   50.00   99.56  15.71
# 25%     84.00  27.86   89.00  113.83  29.59
# 50%    100.00  35.15  101.00  118.21  32.73
# 75%    140.00  39.53  113.00  126.40  37.39
# max    322.00  53.70  160.00  169.60  53.00

# %%
import statsmodels.formula.api as smf
m1_v=smf.ols('MPG~VOL',data = cars).fit()
m1_v.rsquared
# Out:
# 0.2799008651122705

# %%
m1_v.params
# Out:
# Intercept    34.422076
# VOL          -4.801137
# dtype: float64

# %%
m1_w=smf.ols('MPG~WT',data = cars).fit()
np.round(m1_w.rsquared,2)
# Out:
# 0.28

# %%
m1_sp=smf.ols('MPG~SP',data = cars).fit()
m1_sp.rsquared
# Out:
# 0.4721402334141217

# %%
model = smf.ols('MPG~WT+VOL+SP+HP',data=cars_df).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 model = smf.ols('MPG~WT+VOL+SP+HP',data=cars_df).fit()
#
# NameError: name 'cars_df' is not defined

# %%
MPG=0.359028*VOL +0.666047* SP -1.348243 *HP + 0.89
